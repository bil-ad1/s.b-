# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
import seaborn as sb

# %%
u_f = sb.load_dataset('flights')

# %%
yr01 = u_f.passengers[(u_f.year==1949)].sum()

# %%
print(yr01)
# Out:
# 1520

# %%
yr02 = u_f.passengers[(u_f.year==1950)].sum()
yr03 = u_f.passengers[(u_f.year==1951)].sum()
yr04 = u_f.passengers[(u_f.year==1952)].sum()
yr05 = u_f.passengers[(u_f.year==1953)].sum()
yr06 = u_f.passengers[(u_f.year==1954)].sum()
yr07 = u_f.passengers[(u_f.year==1955)].sum()
yr08 = u_f.passengers[(u_f.year==1956)].sum()
yr09 = u_f.passengers[(u_f.year==1957)].sum()
yr10 = u_f.passengers[(u_f.year==1958)].sum()
yr11 = u_f.passengers[(u_f.year==1959)].sum()
yr12 = u_f.passengers[(u_f.year==1960)].sum()

# %%
pp.title('P-> year')
pp.scatter('1949',yr01)
pp.scatter('1950',yr02)
pp.scatter('1951',yr03)
pp.scatter('1952',yr04)
pp.scatter('1953',yr05)
pp.scatter('1954',yr06)
pp.scatter('1955',yr07)
pp.scatter('1956',yr08)
pp.scatter('1957',yr09)
pp.scatter('1958',yr10)
pp.scatter('1959',yr11)
pp.scatter('1960',yr12)

# %%
pp.barh('1949',yr01)
pp.barh('1950',yr02)
pp.barh('1951',yr03)
pp.barh('1952',yr04)
pp.barh('1953',yr05)
pp.barh('1954',yr06)
pp.barh('1955',yr07)
pp.barh('1956',yr08)
pp.barh('1957',yr09)
pp.barh('1958',yr10)
pp.barh('1959',yr11)
pp.barh('1960',yr12)
# Out:
# <BarContainer object of 1 artists>

# %%
sb.barplot(x='month',y='passengers',data=u_f)

# %%
sb.boxplot(x='month',y='passengers',data=u_f)

# %%
sb.displot(x='month',y='passengers',data=u_f)

# %%
sb.catplot(x='month',y='passengers',data=u_f)

# %%
sb.violinplot(x='month',y='passengers',data=u_f)

# %%
sb.lineplot(x='month',y='passengers',data=u_f)

# %%
m01 = u_f.passengers[(u_f.month=='Jan')].sum()
m02 = u_f.passengers[(u_f.month=='Feb')].sum()
m03  = u_f.passengers[(u_f.month=='Mar')].sum()
m04 = u_f.passengers[(u_f.month=='Apr')].sum() 
m05 =  u_f.passengers[(u_f.month=='May')].sum()  
m06 = u_f.passengers[(u_f.month=='Jun')].sum()
m07 = u_f.passengers[(u_f.month=='Jul')].sum()
m08 = u_f.passengers[(u_f.month=='Aug')].sum()
m09 = u_f.passengers[(u_f.month=='Sep')].sum()
m10 = u_f.passengers[(u_f.month=='Oct')].sum()
m11 = u_f.passengers[(u_f.month=='Nov')].sum()
m12 = u_f.passengers[(u_f.month=='Dec')].sum()

# %%
pyi = [m01,m02,m03,m04,m05,m06,m07,m08,m09,m10,m11,m12]
lbs = u_f.month.unique()

# %%
pp.pie(pyi,labels=lbs)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9f7e806210>,
# ...
#  [Text(1.0720780916689665, 0.24626929439828116, 'Jan'),
#   Text(0.861465431446457, 0.6840155776170377, 'Feb'),
#   Text(0.4564466945656876, 1.0008278648299407, 'Mar'),
#   Text(-0.08121921087268759, 1.096997465715039, 'Apr'),
#   Text(-0.6002956003144989, 0.9217620041220269, 'May'),
#   Text(-0.9911824785174697, 0.47702965765240013, 'Jun'),
#   Text(-1.0840147983249617, -0.18684730935309943, 'Jul'),
#   Text(-0.7449997976429765, -0.809305443891195, 'Aug'),
#   Text(-0.14660935619874607, -1.0901860835082189, 'Sep'),
#   Text(0.4260976860573727, -1.0141206841084314, 'Oct'),
#   Text(0.8366508454860658, -0.7141535988479311, 'Nov'),
#   Text(1.0672702605415254, -0.266334734804953, 'Dec')])
